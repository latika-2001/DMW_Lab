# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os                   #importing libraries

# %%
print(os.listdir())         #listing files in current directory
# Out:
# ['.ipynb_checkpoints', 'data1.csv', 'data2.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv('data1.csv')       #reading csv file

# %%
df      #displaying csv file
# Out:
#    Country   Age   Salary Purchased  BirthYear
# 0   France  44.0  72000.0        No       1978
# 1    Spain  27.0  48000.0       Yes       1995
# 2  Germany  30.0  54000.0        No       1992
# 3    Spain  38.0  61000.0        No       1984
# 4  Germany  40.0      NaN       Yes       1982
# 5   France  35.0  58000.0       Yes       1987
# 6    Spain   NaN  52000.0        No       1985
# 7   France  48.0  79000.0       Yes       1974
# 8  Germany  50.0  83000.0        No       1972
# 9   France  37.0  67000.0       Yes       1985

# %%
df.shape       #number of rows and columns in csv file
# Out:
# (10, 5)

# %%
df.isnull().sum()      #number of null values in each column
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# BirthYear    0
# dtype: int64

# %%
df.isnull()          #null values
# Out:
#    Country    Age  Salary  Purchased  BirthYear
# 0    False  False   False      False      False
# 1    False  False   False      False      False
# 2    False  False   False      False      False
# 3    False  False   False      False      False
# 4    False  False    True      False      False
# 5    False  False   False      False      False
# 6    False   True   False      False      False
# 7    False  False   False      False      False
# 8    False  False   False      False      False
# 9    False  False   False      False      False

# %%
df['Age']
# Out:
# 0    44.0
# 1    27.0
# 2    30.0
# 3    38.0
# 4    40.0
# 5    35.0
# 6     NaN
# 7    48.0
# 8    50.0
# 9    37.0
# Name: Age, dtype: float64

# %% [markdown]
# # Replacing Null Values

# %%
avg_age = df['Age'].mean()                      #Average of values in Age Column
avg_salary = df['Salary'].mean()                #Average of values in Salary Column

# %%
avg_age
# Out:
# 38.77777777777778

# %%
avg_salary
# Out:
# 63777.77777777778

# %%
df                       #Displaying csv file before replacing null values
# Out:
#    Country   Age   Salary Purchased  BirthYear
# 0   France  44.0  72000.0        No       1978
# 1    Spain  27.0  48000.0       Yes       1995
# 2  Germany  30.0  54000.0        No       1992
# 3    Spain  38.0  61000.0        No       1984
# 4  Germany  40.0      NaN       Yes       1982
# 5   France  35.0  58000.0       Yes       1987
# 6    Spain   NaN  52000.0        No       1985
# 7   France  48.0  79000.0       Yes       1974
# 8  Germany  50.0  83000.0        No       1972
# 9   France  37.0  67000.0       Yes       1985

# %%
df['Age'].fillna(avg_age, inplace = True)                    #Replacing null values of Age Column with avg_age
df['Salary'].fillna(avg_salary, inplace = True)              #Replacing null values of Salary Column with avg_salary

# %%
df                         #Displaying csv file after replacing null values
# Out:
#    Country        Age        Salary Purchased  BirthYear
# 0   France  44.000000  72000.000000        No       1978
# 1    Spain  27.000000  48000.000000       Yes       1995
# 2  Germany  30.000000  54000.000000        No       1992
# 3    Spain  38.000000  61000.000000        No       1984
# 4  Germany  40.000000  63777.777778       Yes       1982
# 5   France  35.000000  58000.000000       Yes       1987
# 6    Spain  38.777778  52000.000000        No       1985
# 7   France  48.000000  79000.000000       Yes       1974
# 8  Germany  50.000000  83000.000000        No       1972
# 9   France  37.000000  67000.000000       Yes       1985

# %% [markdown]
# # Data Integration

# %%
df1 = pd.read_csv('data2.csv')         #Reading data2.csv file

# %%
df1                                   #Displaying csv file
# Out:
#        Country  Age  Salary Purchased  BirthYear
# 0        India   47   50000       Yes       1975
# 1  South Korea   26   47000       Yes       1996
# 2          USA   42   65000        No       1980

# %%
pd.concat([df,df1]) #Concateneating/integrating two datasets
# Out:
#        Country        Age        Salary Purchased  BirthYear
# 0       France  44.000000  72000.000000        No       1978
# 1        Spain  27.000000  48000.000000       Yes       1995
# 2      Germany  30.000000  54000.000000        No       1992
# 3        Spain  38.000000  61000.000000        No       1984
# 4      Germany  40.000000  63777.777778       Yes       1982
# 5       France  35.000000  58000.000000       Yes       1987
# 6        Spain  38.777778  52000.000000        No       1985
# 7       France  48.000000  79000.000000       Yes       1974
# 8      Germany  50.000000  83000.000000        No       1972
# 9       France  37.000000  67000.000000       Yes       1985
# 0        India  47.000000  50000.000000       Yes       1975
# 1  South Korea  26.000000  47000.000000       Yes       1996
# 2          USA  42.000000  65000.000000        No       1980

# %% [markdown]
# # Data Transformation

# %%
df.hist()  #Displaying histogram of df dataset
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Salary'}>],
#        [<AxesSubplot:title={'center':'BirthYear'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
a = np.array(df['Age'])

# %%
plt.pie(a) #Plotting pie chart of Age column of the dataset
# Out:
# ([<matplotlib.patches.Wedge at 0x1a017756c10>,
#   <matplotlib.patches.Wedge at 0x1a017764130>,
#   <matplotlib.patches.Wedge at 0x1a017764610>,
#   <matplotlib.patches.Wedge at 0x1a017764af0>,
#   <matplotlib.patches.Wedge at 0x1a017764fd0>,
#   <matplotlib.patches.Wedge at 0x1a0177734f0>,
#   <matplotlib.patches.Wedge at 0x1a0177739d0>,
#   <matplotlib.patches.Wedge at 0x1a017773eb0>,
#   <matplotlib.patches.Wedge at 0x1a017780400>,
#   <matplotlib.patches.Wedge at 0x1a0177808e0>],
#  [Text(1.0308490221399966, 0.3838623367211391, ''),
#   Text(0.6561387792377901, 0.8828827228915191, ''),
#   Text(0.19404597347612992, 1.0827493524254361, ''),
#   Text(-0.4014362214241498, 1.0241332726401877, ''),
#   Text(-0.9288668509234734, 0.5892422025411197, ''),
#   Text(-1.0990156623208553, -0.04652498225095924, ''),
#   Text(-0.8822916490134214, -0.65693336502356, ''),
#   Text(-0.24835715687957727, -1.071596343137981, ''),
#   Text(0.5900783014681572, -0.9283359295731555, ''),
#   Text(1.0509493068884415, -0.3248161854814269, '')])

# %%
df['Age'].nunique() #printing no. of unique values which are present in Age column
# Out:
# 10

# %% [markdown]
# # Data Reduction

# %%
df #diplay dataset
# Out:
#    Country        Age        Salary Purchased  BirthYear
# 0   France  44.000000  72000.000000        No       1978
# 1    Spain  27.000000  48000.000000       Yes       1995
# 2  Germany  30.000000  54000.000000        No       1992
# 3    Spain  38.000000  61000.000000        No       1984
# 4  Germany  40.000000  63777.777778       Yes       1982
# 5   France  35.000000  58000.000000       Yes       1987
# 6    Spain  38.777778  52000.000000        No       1985
# 7   France  48.000000  79000.000000       Yes       1974
# 8  Germany  50.000000  83000.000000        No       1972
# 9   France  37.000000  67000.000000       Yes       1985

# %%
df.drop(['BirthYear'], axis=1) #Reducing unnecessary column(s)
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes
